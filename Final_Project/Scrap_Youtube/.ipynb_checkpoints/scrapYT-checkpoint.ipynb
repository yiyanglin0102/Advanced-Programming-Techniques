# %%
import os, sys, re
import requests
import numpy as np
from urllib.parse import urljoin
from bs4 import BeautifulSoup

# %%
def saveFullHtmlPage(url, pagepath='page', session=requests.Session(), html=None):
    """Save web page html and supported contents        
        * pagepath : path-to-page   
        It will create a file  `'path-to-page'.html` and a folder `'path-to-page'_files`
    """
    def savenRename(soup, pagefolder, session, url, tag, inner):
        if not os.path.exists(pagefolder): # create only once
            os.mkdir(pagefolder)
        for res in soup.findAll(tag):   # images, css, etc..
            if res.has_attr(inner): # check inner tag (file object) MUST exists  
                try:
                    filename, ext = os.path.splitext(os.path.basename(res[inner])) # get name and extension
                    filename = re.sub('\W+', '', filename) + ext # clean special chars from name
                    fileurl = urljoin(url, res.get(inner))
                    filepath = os.path.join(pagefolder, filename)
                    # rename html ref so can move html and folder of files anywhere
                    res[inner] = os.path.join(os.path.basename(pagefolder), filename)
                    if not os.path.isfile(filepath): # was not downloaded
                        with open(filepath, 'wb') as file:
                            filebin = session.get(fileurl)
                            file.write(filebin.content)
                except Exception as exc:
                    print(exc, file=sys.stderr)
    if not html:
        html = session.get(url).text
    soup = BeautifulSoup(html, "html.parser")
    path, _ = os.path.splitext(pagepath)
    pagefolder = path+'_files' # page contents folder
    tags_inner = {'img': 'src', 'link': 'href', 'script': 'src'} # tag&inner tags to grab
    for tag, inner in tags_inner.items(): # saves resource files and rename refs
        savenRename(soup, pagefolder, session, url, tag, inner)
    with open(path+'.html', 'wb') as file: # saves modified html doc
        file.write(soup.prettify('utf-8'))

# %%
saveFullHtmlPage('https://www.youtube.com/results?search_query=love', 'love')

# %%
with open("love.html") as fp:
        soup = BeautifulSoup(fp, 'html.parser')

# %%
print(type(soup.select("body")[0].select("script")[13]))
# "videoIds": ["
# Out:
# <class 'bs4.element.Tag'>

# %%
a = soup.select("body")[0]

# %%
paragraphs = []
for x in a:
    paragraphs.append(str(x))

# %%
paragraphs
# Out:
# ['\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'bs\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   ytcfg.set(\'initialBodyClientWidth\', document.body.clientWidth);\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'ai\', null, \'\');}\n  </script>',
#  '\n',
#  '<iframe name="passive_signin" src="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fsignin_passive%26feature%3Dpassive&amp;hl=en" style="display: none">\n</iframe>',
#  '\n',
#  '<ytd-app>\n<ytd-masthead class="shell" id="masthead" logo-type="YOUTUBE_LOGO" slot="masthead">\n<div class="ytd-searchbox-spt" id="search-container" slot="search-container">\n</div>\n<div class="ytd-searchbox-spt" id="search-input" slot="search-input">\n<input autocapitalize="none" autocomplete="off" autocorrect="off" hidden="" id="search" name="search_query" spellcheck="false" tabindex="0" type="text"/>\n</div>\n<svg class="external-icon" id="menu-icon" preserveaspectratio="xMidYMid meet">\n<g class="yt-icons-ext" id="menu" viewbox="0 0 24 24">\n<path d="M21,6H3V5h18V6z M21,11H3v1h18V11z M21,17H3v1h18V17z">\n</path>\n</g>\n</svg>\n<div id="masthead-logo" slot="masthead-logo">\n<a href="/" style="display: none;" title="YouTube">\n<svg class="external-icon" id="yt-logo-updated-svg" viewbox="0 0 90 20">\n<g id="yt-logo-updated" preserveaspectratio="xMidYMid meet" viewbox="0 0 90 20">\n<g>\n<path d="M27.9727 3.12324C27.6435 1.89323 26.6768 0.926623 25.4468 0.597366C23.2197 2.24288e-07 14.285 0 14.285 0C14.285 0 5.35042 2.24288e-07 3.12323 0.597366C1.89323 0.926623 0.926623 1.89323 0.597366 3.12324C2.24288e-07 5.35042 0 10 0 10C0 10 2.24288e-07 14.6496 0.597366 16.8768C0.926623 18.1068 1.89323 19.0734 3.12323 19.4026C5.35042 20 14.285 20 14.285 20C14.285 20 23.2197 20 25.4468 19.4026C26.6768 19.0734 27.6435 18.1068 27.9727 16.8768C28.5701 14.6496 28.5701 10 28.5701 10C28.5701 10 28.5677 5.35042 27.9727 3.12324Z" fill="#FF0000">\n</path>\n<path d="M11.4253 14.2854L18.8477 10.0004L11.4253 5.71533V14.2854Z" fill="white">\n</path>\n</g>\n<g>\n<g id="youtube-paths">\n<path d="M34.6024 13.0036L31.3945 1.41846H34.1932L35.3174 6.6701C35.6043 7.96361 35.8136 9.06662 35.95 9.97913H36.0323C36.1264 9.32532 36.3381 8.22937 36.665 6.68892L37.8291 1.41846H40.6278L37.3799 13.0036V18.561H34.6001V13.0036H34.6024Z">\n</path>\n<path d="M41.4697 18.1937C40.9053 17.8127 40.5031 17.22 40.2632 16.4157C40.0257 15.6114 39.9058 14.5437 39.9058 13.2078V11.3898C39.9058 10.0422 40.0422 8.95805 40.315 8.14196C40.5878 7.32588 41.0135 6.72851 41.592 6.35457C42.1706 5.98063 42.9302 5.79248 43.871 5.79248C44.7976 5.79248 45.5384 5.98298 46.0981 6.36398C46.6555 6.74497 47.0647 7.34234 47.3234 8.15137C47.5821 8.96275 47.7115 10.0422 47.7115 11.3898V13.2078C47.7115 14.5437 47.5845 15.6161 47.3329 16.4251C47.0812 17.2365 46.672 17.8292 46.1075 18.2031C45.5431 18.5771 44.7764 18.7652 43.8098 18.7652C42.8126 18.7675 42.0342 18.5747 41.4697 18.1937ZM44.6353 16.2323C44.7905 15.8231 44.8705 15.1575 44.8705 14.2309V10.3292C44.8705 9.43077 44.7929 8.77225 44.6353 8.35833C44.4777 7.94206 44.2026 7.7351 43.8074 7.7351C43.4265 7.7351 43.156 7.94206 43.0008 8.35833C42.8432 8.77461 42.7656 9.43077 42.7656 10.3292V14.2309C42.7656 15.1575 42.8408 15.8254 42.9914 16.2323C43.1419 16.6415 43.4123 16.8461 43.8074 16.8461C44.2026 16.8461 44.4777 16.6415 44.6353 16.2323Z">\n</path>\n<path d="M56.8154 18.5634H54.6094L54.3648 17.03H54.3037C53.7039 18.1871 52.8055 18.7656 51.6061 18.7656C50.7759 18.7656 50.1621 18.4928 49.767 17.9496C49.3719 17.4039 49.1743 16.5526 49.1743 15.3955V6.03751H51.9942V15.2308C51.9942 15.7906 52.0553 16.188 52.1776 16.4256C52.2999 16.6631 52.5045 16.783 52.7914 16.783C53.036 16.783 53.2712 16.7078 53.497 16.5573C53.7228 16.4067 53.8874 16.2162 53.9979 15.9858V6.03516H56.8154V18.5634Z">\n</path>\n<path d="M64.4755 3.68758H61.6768V18.5629H58.9181V3.68758H56.1194V1.42041H64.4755V3.68758Z">\n</path>\n<path d="M71.2768 18.5634H69.0708L68.8262 17.03H68.7651C68.1654 18.1871 67.267 18.7656 66.0675 18.7656C65.2373 18.7656 64.6235 18.4928 64.2284 17.9496C63.8333 17.4039 63.6357 16.5526 63.6357 15.3955V6.03751H66.4556V15.2308C66.4556 15.7906 66.5167 16.188 66.639 16.4256C66.7613 16.6631 66.9659 16.783 67.2529 16.783C67.4974 16.783 67.7326 16.7078 67.9584 16.5573C68.1842 16.4067 68.3488 16.2162 68.4593 15.9858V6.03516H71.2768V18.5634Z">\n</path>\n<path d="M80.609 8.0387C80.4373 7.24849 80.1621 6.67699 79.7812 6.32186C79.4002 5.96674 78.8757 5.79035 78.2078 5.79035C77.6904 5 ...
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'nc_pj\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'rsbe_dpj\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'js_ld\', null, \'\');}\n  </script>',
#  '\n',
#  '<script id="base-js" nonce="NPMyy92iVwnKYTPPiUYMpA" src="love_files/desktop_polymer_legacy_browsers.js">\n</script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'rsef_dpj\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'rsae_dpj\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'js_r\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'ac\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   var onPolymerReady = function(e) {window.removeEventListener(\'script-load-dpj\', onPolymerReady);if (window.ytcsi) {window.ytcsi.tick(\'apr\', null, \'\');}}; if (window.Polymer && Polymer.RenderStatus) {onPolymerReady();} else {window.addEventListener(\'script-load-dpj\', onPolymerReady);}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'pdc\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   var ytInitialData = {"responseContext":{"serviceTrackingParams":[{"service":"GUIDED_HELP","params":[{"key":"context","value":"yt_web_search"},{"key":"logged_in","value":"0"}]},{"service":"GFEEDBACK","params":[{"key":"has_unlimited_entitlement","value":"False"},{"key":"has_premium_lite_entitlement","value":"False"},{"key":"logged_in","value":"0"},{"key":"e","value":"1714248,23804281,23858057,23882502,23885487,23918597,23934970,23946420,23966208,23983296,23986026,23998056,24001373,24002022,24002025,24004644,24007246,24034168,24036947,24077241,24080738,24120819,24135310,24140247,24152443,24160837,24161116,24162919,24164186,24166867,24169501,24181174,24185614,24187043,24187377,24191629,24197450,24199724,24209349,24211178,24217535,24219713,24229161,24239633,24241378,24248091,24254502,24255165,24255543,24255545,24260783,24262346,24263796,24265820,24267564,24267570,24268142,24271464,24272785,24278596,24279196,24279628,24283093,24283556,24286003,24286010,24286017,24287327,24287795,24288043,24288441,24288912,24290971,24291857,24292955,24292977,24297748,24299747,24299873,24390674,24391539,24392403,24396645,24396719,24398046,24398125,24398595,24399693,24400009,24401558,24402891,24406381,24406983,24408534,24590921,24612269,24613467,24613789,24614043,24615089,39322399,39322504,39322574"}]},{"service":"CSI","params":[{"key":"yt_ad","value":"1"},{"key":"c","value":"WEB"},{"key":"cver","value":"2.20221026.05.00"},{"key":"yt_li","value":"0"},{"key":"GetSearch_rid","value":"0x659686b02bdecfec"}]},{"service":"ECATCHER","params":[{"key":"client.version","value":"2.20221026"},{"key":"client.name","value":"WEB"},{"key":"client.fexp","value":"23858057,24279628,24283556,23946420,24004644,24162919,24007246,24077241,24288441,24283093,23983296,24287795,23986026,24255543,24398595,24160837,24288912,24272785,24002025,24229161,24241378,24152443,24164186,24292977,24288043,24287327,24402891,24255165,24408534,24291857,24187377,24286017,24390674,24140247,24199724,24286003,24286010,24239633,24135310,24262346,24406381,24211178,24398125,24187043,23934970,24614043,24185614,24263796,24613467,1714248,24036947,23998056,24267564,24255545,24260783,24191629,24209349,24254502,24612269,39322399,24292955,24299873,24001373,24290971,24615089,39322504,24265820,24406983,24217535,24034168,24120819,23882502,24613789,39322574,23885487,24299747,24161116,24267570,24166867,24080738,23966208,24169501,23804281,24248091,24181174,24399693,24219713,24279196,24002022,24278596,24400009,23918597,24396645,24268142,24271464,24391539,24398046,24197450,24297748,24396719,24590921,24392403,24401558"}]}],"mainAppWebResponseContext":{"loggedOut":true},"webResponseContextExtensionData":{"ytConfigData":{"visitorData":"Cgt1T3VhOFQ1a1Yzdyj8zYKbBg%3D%3D","rootVisualElementType":4724},"hasDecorated":true}},"estimatedResults":"6116979786","contents":{"twoColumnSearchResultsRenderer":{"primaryContents":{"sectionListRenderer":{"contents":[{"itemSectionRenderer":{"contents":[{"searchPyvRenderer":{"ads":[{"promotedVideoRenderer":{"videoId":"o0WJHVTWGbU","thumbnail":{"thumbnails":[{"url":"https://i1.ytimg.com/vi/o0WJHVTWGbU/0.jpg"}]},"title":{"simpleText":"5 Mistakes Women Make When A Man Pulls Away And What to Do Instead"},"description":{"simpleText":"When he pulls away, what not to do And here\'s you should do instead."},"longBylineText":{"runs":[{"text":"Matthew Coast","navigationEndpoint":{"clickTrackingParams":"COcBENG4BxgAIhMIqZ7335iM-wIVRLycCh2JyQZ0","commandMetadata":{"webCommandMetadata":{"url":"/channel/UCcL9spxJvF7ET57igXURwOw","webPageType":"WEB_PAGE_TYPE_CHANNEL","rootVe":3611,"apiUrl":"/youtubei/v1/browse"}},"browseEndpoint":{"browseId":"UCcL9spxJvF7ET57igXURwOw","canonicalBaseUrl":"/channel/UCcL9spxJvF7ET57igXURwOw"}}}]},"shortBylineText":{"runs":[{"text":"Matthew Coast","navigationEndpoint":{"clickTrackingParams":"COcBENG4BxgAIhMIqZ7335iM-wIVRLycCh2JyQZ0","commandMetadata":{"webCommandMetadata":{"url":"/channel/UCcL9spxJvF7ET57igXURwOw","webPageType" ...
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'pdr\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   (function serverContract() {window[\'ytPageType\'] = "search";window[\'ytCommand\'] = {"clickTrackingParams":"IhMIkan235iM-wIVz7qcCh108Q_SMghleHRlcm5hbA==","commandMetadata":{"webCommandMetadata":{"url":"/results?search_query=love","webPageType":"WEB_PAGE_TYPE_SEARCH","rootVe":4724}},"searchEndpoint":{"query":"love"}};window[\'ytUrl\'] = \'\\/results?search_query\\x3dlove\';/*\n\n Copyright The Closure Library Authors.\n SPDX-License-Identifier: Apache-2.0\n*/\nvar a=window;(function(e){var c=window;c.getInitialCommand=function(){return e};c.loadInitialCommand&&c.loadInitialCommand(c.getInitialCommand())})(a.ytCommand);\n(function(e,c,l,f,g,h,k){var d=window;d.getInitialData=function(){var b=window;b.ytcsi&&b.ytcsi.tick("pr",null,"");b={page:e,endpoint:c,response:l};f&&(b.playerResponse=f);g&&(b.reelWatchSequenceResponse=g);k&&(b.url=k);h&&(b.previousCsn=h);return b};d.loadInitialData&&d.loadInitialData(d.getInitialData())})(a.ytPageType,a.ytCommand,a.ytInitialData,a.ytInitialPlayerResponse,a.ytInitialReelWatchSequenceResponse,a.ytPreviousCsn,a.ytUrl);\n})();\n  </script>',
#  '\n',
#  '<link href="love_files/wwwmaindesktopwatchpageskeleton.css" name="www-main-desktop-watch-page-skeleton" nonce="-g194eFXAj2qRoObtJDuuw" rel="stylesheet"/>',
#  '\n',
#  '<div class="watch-skeletonhidden" id="watch-page-skeleton" rounded-container="">\n<div id="container">\n<div id="related">\n<div class="autoplay skeleton-light-border-bottom">\n<div class="skeleton-bg-color" id="upnext">\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="video-skeleton">\n<div class="video-details">\n<div class="thumbnail skeleton-bg-color">\n</div>\n<div class="details flex-1">\n<div class="video-title text-shell skeleton-bg-color">\n</div>\n<div class="video-meta text-shell skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n</div>\n<div id="info-container">\n<div class="skeleton-light-border-bottom" id="primary-info">\n<div class="text-shell skeleton-bg-color" id="title">\n</div>\n<div id="info">\n<div class="text-shell skeleton-bg-color" id="count">\n</div>\n<div class="flex-1">\n</div>\n<div id="menu">\n<div class="menu-button skeleton-bg-color">\n</div>\n<div class="menu-button skeleton-bg-color">\n</div>\n<div class="menu-button skeleton-bg-color">\n</div>\n<div class="menu-button skeleton-bg-color">\n</div>\n<div class="menu-button skeleton-bg-color">\n</div>\n</div>\n</div>\n</div>\n<div class="skeleton-light-border-bottom" id="secondary-info">\n<div id="top-row">\n<div class="flex-1" id="video-owner">\n<div class="skeleton-bg-color" id="channel-icon">\n</div>\n<div class="flex-1" id="upload-info">\n<div class="text-shell skeleton-bg-color" id="owner-n ...
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.tick(\'gcc\', null, \'\');}\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   ytcfg.set({"CSI_SERVICE_NAME": \'youtube\', "TIMING_INFO": {"GetSearch_rid": \'0x659686b02bdecfec\',"yt_ad": \'1\',}})\n  </script>',
#  '\n',
#  '<script nonce="NPMyy92iVwnKYTPPiUYMpA">\n   if (window.ytcsi) {window.ytcsi.info(\'st\',  984.0 , \'\');}\n  </script>',
#  '\n']

# %%
for i, a in enumerate(paragraphs):
    if "\"videoIds\":[\"" in a:
        b = paragraphs[31]

# %%
"\"videoIds\":[\"" in b
# Out:
# True

# %%
match=(re.search("videoIds", b))

# %%
match
# Out:
# <re.Match object; span=(18170, 18178), match='videoIds'>

# %%
b[7998: 8009]
# Out:
# 'P0ANd7b8IT_'

# %%
result = [_.start() for _ in re.finditer("\"videoIds\":", b)]
result
# Out:
# [18169,
#  18216,
#  21094,
#  21141,
#  26121,
#  26168,
#  29021,
#  29068,
#  34249,
#  34296,
#  37201,
#  37248,
#  42042,
#  42089,
#  45019,
#  45066,
#  50275,
#  50322,
#  53198,
#  53245,
#  73496,
#  73543,
#  76438,
#  76485,
#  81866,
#  81913,
#  84764,
#  84811,
#  90156,
#  90203,
#  92920,
#  92967,
#  98100,
#  98147,
#  101022,
#  101069,
#  106101,
#  106148,
#  109026,
#  109073,
#  113852,
#  113899,
#  116779,
#  116826,
#  121855,
#  121902,
#  124810,
#  124857,
#  129606,
#  129653,
#  132533,
#  132580,
#  137037,
#  137084,
#  139991,
#  140038,
#  144901,
#  144948,
#  147869,
#  147916,
#  152743,
#  152790,
#  155696,
#  155743,
#  160295,
#  160342,
#  163210,
#  163257,
#  168817,
#  168864,
#  171715,
#  171762,
#  181246,
#  181293,
#  184199,
#  184246,
#  188820,
#  188867,
#  191743,
#  191790,
#  196747,
#  196794,
#  199728,
#  199775,
#  204281,
#  204328,
#  207229,
#  207276,
#  212122,
#  212169,
#  215044,
#  215091,
#  219741,
#  219788,
#  222705,
#  222752,
#  227537,
#  227584,
#  230459,
#  230506,
#  235397,
#  235444,
#  238322,
#  238369,
#  242770,
#  242817,
#  245687,
#  245734,
#  250786,
#  250833,
#  253719,
#  253766,
#  258350,
#  258397,
#  261282,
#  261329,
#  267995,
#  268042,
#  270997,
#  271044,
#  276036,
#  276083,
#  278961,
#  279008,
#  283562,
#  283609,
#  286479,
#  286526,
#  291509,
#  291556,
#  294407,
#  294454,
#  299637,
#  299684,
#  302535,
#  302582,
#  307277,
#  307324,
#  310202,
#  310249,
#  315123,
#  315170,
#  318102,
#  318149,
#  322599,
#  322646,
#  325509,
#  325556,
#  330736,
#  330783,
#  333636,
#  333683]

# %%
b[7985]+ b[7986] + b[7987]+ b[7988]+ b[7989]+ b[7990]+ b[7991]+ b[7992]+ b[7993]+ b[7994]+ b[7995]+ b[7996]
# Out:
# 'vaA6gDBKoE_Q'

# %%
result
# Out:
# [18169,
#  18216,
#  21094,
#  21141,
#  26121,
#  26168,
#  29021,
#  29068,
#  34249,
#  34296,
#  37201,
#  37248,
#  42042,
#  42089,
#  45019,
#  45066,
#  50275,
#  50322,
#  53198,
#  53245,
#  73496,
#  73543,
#  76438,
#  76485,
#  81866,
#  81913,
#  84764,
#  84811,
#  90156,
#  90203,
#  92920,
#  92967,
#  98100,
#  98147,
#  101022,
#  101069,
#  106101,
#  106148,
#  109026,
#  109073,
#  113852,
#  113899,
#  116779,
#  116826,
#  121855,
#  121902,
#  124810,
#  124857,
#  129606,
#  129653,
#  132533,
#  132580,
#  137037,
#  137084,
#  139991,
#  140038,
#  144901,
#  144948,
#  147869,
#  147916,
#  152743,
#  152790,
#  155696,
#  155743,
#  160295,
#  160342,
#  163210,
#  163257,
#  168817,
#  168864,
#  171715,
#  171762,
#  181246,
#  181293,
#  184199,
#  184246,
#  188820,
#  188867,
#  191743,
#  191790,
#  196747,
#  196794,
#  199728,
#  199775,
#  204281,
#  204328,
#  207229,
#  207276,
#  212122,
#  212169,
#  215044,
#  215091,
#  219741,
#  219788,
#  222705,
#  222752,
#  227537,
#  227584,
#  230459,
#  230506,
#  235397,
#  235444,
#  238322,
#  238369,
#  242770,
#  242817,
#  245687,
#  245734,
#  250786,
#  250833,
#  253719,
#  253766,
#  258350,
#  258397,
#  261282,
#  261329,
#  267995,
#  268042,
#  270997,
#  271044,
#  276036,
#  276083,
#  278961,
#  279008,
#  283562,
#  283609,
#  286479,
#  286526,
#  291509,
#  291556,
#  294407,
#  294454,
#  299637,
#  299684,
#  302535,
#  302582,
#  307277,
#  307324,
#  310202,
#  310249,
#  315123,
#  315170,
#  318102,
#  318149,
#  322599,
#  322646,
#  325509,
#  325556,
#  330736,
#  330783,
#  333636,
#  333683]

# %%
result = np.add(result, 13).tolist()

# %%
result
# Out:
# [18182,
#  18229,
#  21107,
#  21154,
#  26134,
#  26181,
#  29034,
#  29081,
#  34262,
#  34309,
#  37214,
#  37261,
#  42055,
#  42102,
#  45032,
#  45079,
#  50288,
#  50335,
#  53211,
#  53258,
#  73509,
#  73556,
#  76451,
#  76498,
#  81879,
#  81926,
#  84777,
#  84824,
#  90169,
#  90216,
#  92933,
#  92980,
#  98113,
#  98160,
#  101035,
#  101082,
#  106114,
#  106161,
#  109039,
#  109086,
#  113865,
#  113912,
#  116792,
#  116839,
#  121868,
#  121915,
#  124823,
#  124870,
#  129619,
#  129666,
#  132546,
#  132593,
#  137050,
#  137097,
#  140004,
#  140051,
#  144914,
#  144961,
#  147882,
#  147929,
#  152756,
#  152803,
#  155709,
#  155756,
#  160308,
#  160355,
#  163223,
#  163270,
#  168830,
#  168877,
#  171728,
#  171775,
#  181259,
#  181306,
#  184212,
#  184259,
#  188833,
#  188880,
#  191756,
#  191803,
#  196760,
#  196807,
#  199741,
#  199788,
#  204294,
#  204341,
#  207242,
#  207289,
#  212135,
#  212182,
#  215057,
#  215104,
#  219754,
#  219801,
#  222718,
#  222765,
#  227550,
#  227597,
#  230472,
#  230519,
#  235410,
#  235457,
#  238335,
#  238382,
#  242783,
#  242830,
#  245700,
#  245747,
#  250799,
#  250846,
#  253732,
#  253779,
#  258363,
#  258410,
#  261295,
#  261342,
#  268008,
#  268055,
#  271010,
#  271057,
#  276049,
#  276096,
#  278974,
#  279021,
#  283575,
#  283622,
#  286492,
#  286539,
#  291522,
#  291569,
#  294420,
#  294467,
#  299650,
#  299697,
#  302548,
#  302595,
#  307290,
#  307337,
#  310215,
#  310262,
#  315136,
#  315183,
#  318115,
#  318162,
#  322612,
#  322659,
#  325522,
#  325569,
#  330749,
#  330796,
#  333649,
#  333696]

# %%
settt = set()
for n in result:
    settt.add(b[n:n+11])

# %%
settt = list(settt)

# %%
settt
# Out:
# ['Jkj36B1YuDU',
#  '384m35jT0Vg',
#  '4-3xejuhTM8',
#  '3SaVOpgSa6M',
#  'ZqK2As0qimM',
#  'iZxvjm9eFIU',
#  'Jg1j5Ed_zt4',
#  'ePri1ISS49Y',
#  'bgjUzhdmmF0',
#  'DWSYVCuLmZI',
#  '72DPj02EsSY',
#  '0pObLdN9ICg',
#  'dNtcLPDSwB0',
#  '9PBZy9j3H3I',
#  'Kb8LYQIiUwk',
#  'LEBUgI0WeOI',
#  'w6NxHj3L_XY',
#  'UrD4sGLLcxY',
#  'w9_-SCFNeag',
#  'Zy0r41QfZ-Q',
#  'KTkW636B8xg',
#  'arCTOMGT9do',
#  'VvMHkN3dOfU',
#  'UZWmtxLiiFE',
#  'vpUb3mOhRnk',
#  'PxeQfYWikvI',
#  'nWIVlbYEtVg',
#  'tmSzRx9RYLk',
#  'ox7RsX1Ee34',
#  'nwPAfB53Uec',
#  'omEuqt19Uhs',
#  'iz3BtgPmBU0',
#  'DRg7cbsFJ34',
#  'vqyX7vihxHY',
#  'OIKC2ggCed4',
#  'QZoUs8aeovY',
#  'f_HmF84G7ZY',
#  'daPJTxuY7G8']

# %%
for i in range(len(settt)):
    settt[i] = "youtube.com/watch?v=" + settt[i]

# %%
settt
# Out:
# ['youtube.com/watch?v=Jkj36B1YuDU',
#  'youtube.com/watch?v=384m35jT0Vg',
#  'youtube.com/watch?v=4-3xejuhTM8',
#  'youtube.com/watch?v=3SaVOpgSa6M',
#  'youtube.com/watch?v=ZqK2As0qimM',
#  'youtube.com/watch?v=iZxvjm9eFIU',
#  'youtube.com/watch?v=Jg1j5Ed_zt4',
#  'youtube.com/watch?v=ePri1ISS49Y',
#  'youtube.com/watch?v=bgjUzhdmmF0',
#  'youtube.com/watch?v=DWSYVCuLmZI',
#  'youtube.com/watch?v=72DPj02EsSY',
#  'youtube.com/watch?v=0pObLdN9ICg',
#  'youtube.com/watch?v=dNtcLPDSwB0',
#  'youtube.com/watch?v=9PBZy9j3H3I',
#  'youtube.com/watch?v=Kb8LYQIiUwk',
#  'youtube.com/watch?v=LEBUgI0WeOI',
#  'youtube.com/watch?v=w6NxHj3L_XY',
#  'youtube.com/watch?v=UrD4sGLLcxY',
#  'youtube.com/watch?v=w9_-SCFNeag',
#  'youtube.com/watch?v=Zy0r41QfZ-Q',
#  'youtube.com/watch?v=KTkW636B8xg',
#  'youtube.com/watch?v=arCTOMGT9do',
#  'youtube.com/watch?v=VvMHkN3dOfU',
#  'youtube.com/watch?v=UZWmtxLiiFE',
#  'youtube.com/watch?v=vpUb3mOhRnk',
#  'youtube.com/watch?v=PxeQfYWikvI',
#  'youtube.com/watch?v=nWIVlbYEtVg',
#  'youtube.com/watch?v=tmSzRx9RYLk',
#  'youtube.com/watch?v=ox7RsX1Ee34',
#  'youtube.com/watch?v=nwPAfB53Uec',
#  'youtube.com/watch?v=omEuqt19Uhs',
#  'youtube.com/watch?v=iz3BtgPmBU0',
#  'youtube.com/watch?v=DRg7cbsFJ34',
#  'youtube.com/watch?v=vqyX7vihxHY',
#  'youtube.com/watch?v=OIKC2ggCed4',
#  'youtube.com/watch?v=QZoUs8aeovY',
#  'youtube.com/watch?v=f_HmF84G7ZY',
#  'youtube.com/watch?v=daPJTxuY7G8']
