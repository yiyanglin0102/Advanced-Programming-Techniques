# %%
#!/usr/bin/env python
# coding: utf-8

import os, sys, re, subprocess, requests, numpy as np, glob
from urllib.parse import urljoin
from bs4 import BeautifulSoup

keyWord = 'love'
keword = '#' + keyWord

# %%
from instaloader import Instaloader, Profile, instaloader

# %%
# L = Instaloader()
# posts = instaloader.Hashtag.from_name(L.context, "#cat").get_posts()

# for post in posts:
#     L.download_post(post, "#cat")

# %%
subprocess.run('instaloader --login=ylin363 --post-filter="is_video"  "#cat"', shell=True)

# for i in range(1):  
#     subprocess.run('youtube-dl -f worstvideo[ext=mp4] '+ vidoes[i], shell=True)
#     subprocess.run('scenedetect --input *.mp4 detect-content save-images', shell=True)
#     subprocess.run('magick *.jpg images.gif', shell=True)
#     subprocess.run('rm -rf *.jpg', shell=True)
# Out:
# Only download posts with property "is_video".
# Loaded session from /Users/yiyanglin/.config/instaloader/session-ylin363.
# Logged in as ylin363.
# #cat/2022-11-19_15-56-59_UTC_profile_pic.jpg
# Retrieving pictures with hashtag #cat...
# [  1] #cat/2022-11-19_19-42-31_UTC.jpg [𝙏𝙞𝙢𝙚 𝙨𝙥𝙚𝙣𝙩 𝙬𝙞𝙩𝙝 𝙘𝙖𝙩𝙨 𝙞𝙨 𝙩𝙞𝙢𝙚 …] #cat/2022-11-19_19-42-31_UTC.mp4 json
# [  2] <Post ClJ5epBLTkW> skipped
# [  3] <Post ClJ5eZKyOAL> skipped
# [  4] <Post ClJ5eKtLM_W> skipped
# [  5] <Post ClJ5d85Nmeu> skipped
# [  6] <Post ClJ5d5VP2ZX> skipped
# [  7] <Post ClJ5dj7rGXa> skipped
# [  8] <Post ClJ5dY7vu6Y> skipped
# [  9] <Post ClJ5dUTDpAS> skipped
# [ 10] <Post ClJ5dNEBr0F> skipped
# [ 11] <Post ClJ5cpusSEs> skipped
# [ 12] <Post ClJ5cM8LUK9> skipped
# [ 13] <Post ClJ5b3Qg0Ry> skipped
# [ 14] <Post ClJ5bgWqktn> skipped
# [ 15] <Post ClJ5bZWsBCg> skipped
# [ 16] <Post ClJ5bN3OQhj> skipped
# [ 17] <Post ClJ5afxJwh5> skipped
# [ 18] <Post ClJ5aX_y55j> skipped
# [ 19] <Post ClJ5Z3MMJoK> skipped
# ...

# %%
len(os.listdir('.'))
# Out:
# 5

# %%
os.listdir('.')
# Out:
# ['.DS_Store',
#  'gallery-dl',
#  '#cat',
#  'Download-Instag.ipynb',
#  '.ipynb_checkpoints']

# %%
# Out:
# '/Users/yiyanglin/Desktop/CS622/Final_Project/Instagram_Download'

# %%
subprocess.run('cd "#cat"', shell=True)
os.getcwd()
# Out:
# '/Users/yiyanglin/Desktop/CS622/Final_Project/Instagram_Download'

# %%
os.getcwd()
# Out:
# '/Users/yiyanglin/Desktop/CS622/Final_Project/Instagram_Download'
